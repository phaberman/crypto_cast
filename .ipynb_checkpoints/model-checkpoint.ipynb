# %%
# Import packages
import pandas as pd
from prophet import Prophet
import plotly
from prophet.plot import plot_plotly, plot_components_plotly
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric

# %%
# Import data
def import_data():
    path = 'data/btc_clean.csv'
    return pd.read_csv(path, parse_dates=['ds'])

# %%
df = import_data()

# %%
df.tail()
# Out:
#              ds         y
# 2552 2021-12-27  50803.91
# 2553 2021-12-28  50706.26
# 2554 2021-12-29  47546.08
# 2555 2021-12-30  46415.57
# 2556 2021-12-31  47142.59

# %%
# Instantiate model
m = Prophet()

# %%
# Fit model
m.fit(df)
# Out:
# 17:43:24 - cmdstanpy - INFO - Chain [1] start processing
# 17:43:25 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create future dataframe
future = m.make_future_dataframe(periods=365)

# %%
# Make prediction
forecast = m.predict(future)

# %%
# Check forecast
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower     yhat_upper
# 2917 2022-12-27  95791.800435  88186.056876  104183.586594
# 2918 2022-12-28  96066.912991  88589.738335  103742.790458
# 2919 2022-12-29  96425.672207  88249.625219  104894.289346
# 2920 2022-12-30  96707.240376  88984.435868  104655.780392
# 2921 2022-12-31  97100.337359  89149.880569  104929.667008

# %%
# Plot forecast
fig1 = m.plot(forecast)

# %%
# Plot components
fig2 = m.plot_components(forecast)

# %% [markdown]
# # Cross Validation

# %%
initial = str(len(df) - 366) + ' days'
period = str(180) + ' days'
horizon = str(365) + ' days'

df_cv = cross_validation(m, initial=initial, period=period, horizon=horizon)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 17:43:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:43:58 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_cv.head()
# Out:
#           ds          yhat    yhat_lower    yhat_upper         y     cutoff
# 0 2021-01-01  16303.527025  14391.312973  18073.811931  29017.13 2020-12-31
# 1 2021-01-02  16223.624107  14399.401485  17882.916379  29385.87 2020-12-31
# 2 2021-01-03  16145.927596  14291.891147  18068.108908  32238.95 2020-12-31
# 3 2021-01-04  16031.776739  13993.752008  17993.223127  33124.56 2020-12-31
# 4 2021-01-05  15957.831877  14182.894469  17877.054235  32118.23 2020-12-31

# %%
# Performance
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon           mse          rmse           mae      mape     mdape  \
# 0 36 days  3.893387e+08  19731.667381  19497.592994  0.557929  0.566328
# 1 37 days  4.001783e+08  20004.456868  19796.985301  0.562761  0.567438
# 2 38 days  4.114196e+08  20283.480770  20099.150816  0.567458  0.570934
# 3 39 days  4.202602e+08  20500.248283  20319.510058  0.570728  0.576746
# 4 40 days  4.400552e+08  20977.493487  20725.220143  0.575264  0.579661
#
#       smape  coverage
# 0  0.776158       0.0
# 1  0.785073       0.0
# 2  0.793827       0.0
# 3  0.800127       0.0
# 4  0.809385       0.0

# %%
# Plot MAPE
fig = plot_cross_validation_metric(df_cv, metric='mape')
