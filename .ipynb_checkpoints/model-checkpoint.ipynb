# %%
# Import packages
import pandas as pd
from sklearn.metrics import r2_score

# %%
# Import data
def import_data():
    path = 'data/btc_clean.csv'
    df = pd.read_csv(path, parse_dates=['ds'])
    return df.set_index('ds')

# %%
# Load dataframe
df = import_data()

# %%
# Train/test split sizes
train_size = 0.6
index = round(train_size*df.shape[0])

# Create train/test split dataframes
df_train = df.iloc[:index]
df_test = df.iloc[index:]

# %%
# Baseline prediction (next day)
y_pred = df_test.shift(1)

y_pred = df_test.shift(1).dropna()
y_true = df_test[1:]

print(f"R2: {r2_score(y_true, y_pred)}")
# Out:
# R2: 0.9961317068954247

# %%
# Linear model with 12 autoregressive features
df2 = df.copy()
df2_train = df_train.copy()
df2_test = df_test.copy()

for i in range(1, 13):
    df2_train[f't - {i}'] = df_train['y'].shift(i)
    df2_test[f't - {i}'] = df_test['y'].shift(i)

df2_train.dropna(inplace=True)
df2_test.dropna(inplace=True)

df2_train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/crypto_cast/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/crypto_cast/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/crypto_cast/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [49], in <cell line: 6>()
#       4 df2_test = df_test.copy()
#       6 for i in range(1, 13):
# ----> 7     df2_train[f't - {i}'] = df_train['value'].shift(i)
#       8     df2_test[f't - {i}'] = df_test['value'].shift(i)
#      10 df2_train.dropna(inplace=True)
#
# File ~/.pyenv/versions/3.8.12/envs/crypto_cast/lib/python3.8/site-packages/pandas/core/frame.py:3506, in DataFrame.__getitem__(self, key)
#    3504 if self.columns.nlevels > 1:
#    3505     return self._getitem_multilevel(key)
# -> 3506 indexer = self.columns.get_loc(key)
#    3507 if is_integer(indexer):
#    3508     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.12/envs/crypto_cast/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'value'
